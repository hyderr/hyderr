# %%
import pandas as pd

# %%
flight_dataset = pd.read_excel('Desktop/flight excel.xlsx')

# %%
flight_dataset.shape
# Out:
# (7698, 14)

# %%
flight_dataset.head()
# Out:
#    Airport ID                                         Name          City  \
# 0           1                               Goroka Airport        Goroka
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#             Tz database     Type       Source
# ...

# %%
flight_dataset.columns
# Out:
# Index(['Airport ID', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude',
#        'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database', 'Type',
#        'Source'],
#       dtype='object')

# %%
#NOW CREATE A NEW DATAFRAME WITH ONLY REQUIRED COLUMNS
df_analyze_dataset = flight_dataset[['Airport ID','Name','Country','Altitude','DST','Tz database']]

# %%
type(df_analyze_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
df_analyze_dataset.head()
# Out:
#    Airport ID                                         Name           Country  \
# 0           1                               Goroka Airport  Papua New Guinea
# 1           2                               Madang Airport  Papua New Guinea
# 2           3                 Mount Hagen Kagamuga Airport  Papua New Guinea
# 3           4                               Nadzab Airport  Papua New Guinea
# 4           5  Port Moresby Jacksons International Airport  Papua New Guinea
#
#    Altitude DST           Tz database
# 0      5282   U  Pacific/Port_Moresby
# 1        20   U  Pacific/Port_Moresby
# 2      5388   U  Pacific/Port_Moresby
# 3       239   U  Pacific/Port_Moresby
# 4       146   U  Pacific/Port_Moresby

# %%
df_analyze_dataset.shape
# Out:
# (7698, 6)

# %%
#drop the values where altitude is not available
df_analyze_dataset = df_analyze_dataset.dropna(subset=['Altitude'])

# %%
df_analyze_dataset.shape
# Out:
# (7698, 6)

# %%
#gropup by country
airport_country = df_analyze_dataset.groupby('Country')

# %%
#view themby country using size method
airport_country.size()
# Out:
# Country
# Afghanistan                         22
# Albania                              5
# Algeria                             44
# American Samoa                       2
# Angola                              25
# Anguilla                             1
# Antarctica                           7
# Antigua and Barbuda                  2
# Argentina                           96
# Armenia                              5
# Aruba                                1
# Australia                          334
# Austria                             20
# Azerbaijan                           8
# Bahamas                             34
# Bahrain                              2
# Bangladesh                          10
# Barbados                             1
# Belarus                             12
# Belgium                             24
# Belize                               3
# Benin                                3
# Bermuda                              1
# Bhutan                               3
# ...

# %%
#now group by DST
Daylight_savings_time = df_analyze_dataset.groupby('DST')

# %%
Daylight_savings_time.size()
# Out:
# DST
# A     1777
# E     1610
# N     1402
# O      225
# S      412
# U     1862
# Z       57
# \N     353
# dtype: int64

# %%
new_zeland_dst = Daylight_savings_time.get_group('Z')

# %%
new_zeland_dst
# Out:
#       Airport ID                                Name      Country  Altitude  \
# 1936        2006      Auckland International Airport  New Zealand        23
# 1937        2007                       Taupo Airport  New Zealand      1335
# 1938        2008                     Ardmore Airport  New Zealand       111
# 1939        2009  Christchurch International Airport  New Zealand       123
# 1940        2010       Chatham Islands-Tuuta Airport  New Zealand        43
# 1941        2011                     Dunedin Airport  New Zealand         4
# 1942        2012                    Gisborne Airport  New Zealand        15
# 1943        2013                  Glentanner Airport  New Zealand      1824
# 1944        2014                   Hokitika Airfield  New Zealand       146
# 1945        2015      Hamilton International Airport  New Zealand       172
# 1946        2016                  Hastings Aerodrome  New Zealand        72
# ...
